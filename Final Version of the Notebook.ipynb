# %% [markdown]
# # Final Version of Notebook: Analyzing COVID-19 Data in Python

# %% [markdown]
# COVID-19 is a virus, declared a pandemic by the World Health Organization, that has spread to a number of countries worldwide.

# %% [markdown]
# # Data Source

# %%
# %matplotlib inline
import pandas

# %% [markdown]
# # Imported Data From S3 Bucket

# %%
df = pandas.read_excel('s3://kropff-ia241/COVID-19-geographic-disbtribution-worldwide-2020-05-01.xlsx')
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-05-01    1      5  2020    222       4             Afghanistan
# 1     2020-04-30   30      4  2020    122       0             Afghanistan
# 2     2020-04-29   29      4  2020    124       3             Afghanistan
# 3     2020-04-28   28      4  2020    172       0             Afghanistan
# 4     2020-04-27   27      4  2020     68      10             Afghanistan
# 5     2020-04-26   26      4  2020    112       4             Afghanistan
# 6     2020-04-25   25      4  2020     70       1             Afghanistan
# 7     2020-04-24   24      4  2020    105       2             Afghanistan
# 8     2020-04-23   23      4  2020     84       4             Afghanistan
# 9     2020-04-22   22      4  2020     61       1             Afghanistan
# 10    2020-04-21   21      4  2020     35       2             Afghanistan
# 11    2020-04-20   20      4  2020     88       3             Afghanistan
# ...

# %% [markdown]
# # Number of Deaths Per Date

# %%
death_per_date= df.groupby('dateRep').sum()['deaths']
death_per_date
# Out:
# dateRep
# 2019-12-31        0
# 2020-01-01        0
# 2020-01-02        0
# 2020-01-03        0
# 2020-01-04        0
# 2020-01-05        0
# 2020-01-06        0
# 2020-01-07        0
# 2020-01-08        0
# 2020-01-09        0
# 2020-01-10        0
# 2020-01-11        1
# 2020-01-12        0
# 2020-01-13        0
# 2020-01-14        0
# 2020-01-15        1
# 2020-01-16        0
# 2020-01-17        0
# 2020-01-18        0
# 2020-01-19        1
# 2020-01-20        0
# 2020-01-21        3
# 2020-01-22       11
# 2020-01-23        0
# 2020-01-24        9
# 2020-01-25       15
# 2020-01-26       15
# 2020-01-27       25
# 2020-01-28       25
# 2020-01-29       26
#               ...
# 2020-04-02     4907
# 2020-04-03     4956
# 2020-04-04     6633
# 2020-04-05     6145
# 2020-04-06     4678
# 2020-04-07     5266
# 2020-04-08     7663
# 2020-04-09     6436
# 2020-04-10     7445
# 2020-04-11     7221
# 2020-04-12     6026
# 2020-04-13     5266
# 2020-04-14     5371
# 2020-04-15     7604
# ...

# %% [markdown]
# This data set was calculated to find the total number of deaths per day (grouped by date).

# %%
death_per_date.plot()

# %% [markdown]
# The number of deaths per day began increasing at the beginning of March and continues increasing into May.

# %% [markdown]
# # Top 20 Countries with the Highest Number of Cases

# %%
sum_cases_by_country = df.groupby('countriesAndTerritories').sum()['cases']
sum_cases_by_country.nlargest(20).plot.bar()

# %% [markdown]
# This calculation finds the top 20 countries with the highest number of total cases.

# %% [markdown]
# The United States of America is the country that has the highest number of cases. Spain has the second highest number and Italy is third.

# %% [markdown]
# # The Average Number of Cases per Date (For top 20 countries)

# %%
avg_cases_per_date= df.groupby('dateRep').mean()['cases']

avg_cases_per_date.nlargest(20).plot()

# %% [markdown]
# This graph calculates the average number of cases per day and it is grouped by the date.

# %% [markdown]
# With a data pool of the top 20 countries with the highest number of cases, April 26th had the highest number of average cases.

# %% [markdown]
# # China Data Set

# %%
china_data = df.loc[df['countriesAndTerritories'] == 'China']
china_data[:20] #the top 15 rows
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 2791 2020-05-01    1      5  2020     12       0                   China
# 2792 2020-04-30   30      4  2020      4       0                   China
# 2793 2020-04-29   29      4  2020      2       0                   China
# 2794 2020-04-28   28      4  2020     26       0                   China
# 2795 2020-04-27   27      4  2020      3       1                   China
# 2796 2020-04-26   26      4  2020     10       0                   China
# 2797 2020-04-25   25      4  2020     15       0                   China
# 2798 2020-04-24   24      4  2020      8       0                   China
# 2799 2020-04-23   23      4  2020     12       0                   China
# 2800 2020-04-22   22      4  2020     15       0                   China
# 2801 2020-04-21   21      4  2020     32       0                   China
# 2802 2020-04-20   20      4  2020     14       0                   China
# ...

# %% [markdown]
# # China Number of Cases per Day

# %%
china_data.plot(x='dateRep',y='cases')

# %% [markdown]
# This calculation finds the total number of cases per day (grouped by date).

# %% [markdown]
# The COVID-19 virus is known to have begun in China, and this graph shows that the number of cases per day was the highest mid-February, above 14,000, and then began decreasing.

# %% [markdown]
# # Conclusion

# %% [markdown]
# This data concludes that the month of April had the highest number of increasing cases and the United States has the highest number of cases in the world. The data from China shows that the number of cases will peak and then begin decreasing, so other countries may experience similar trends. The limitations of this data is that the visualizations can't represent every country and the dataset is very large, as well as there is limited testing and limits to the data collection.
